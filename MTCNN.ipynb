# %% [markdown]
# <a href="https://colab.research.google.com/github/padmacharan-123/AAI-LAB/blob/main/MTCNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install mtcnn opencv-python matplotlib tqdm
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 22.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 69.9 MB/s eta 0:00:00
# ...

# %%
import cv2
import os
import matplotlib.pyplot as plt
from mtcnn import MTCNN
from tqdm import tqdm

# %%
# Download dataset
# !wget http://vis-www.cs.umass.edu/fddb/originalPics.tar.gz
# !wget http://vis-www.cs.umass.edu/fddb/FDDB-folds.tgz

# Extract dataset
# !tar -xvf originalPics.tar.gz
# !tar -xvf FDDB-folds.tgz
# Out:
# --2026-04-06 23:17:04--  http://vis-www.cs.umass.edu/fddb/originalPics.tar.gz
# Resolving vis-www.cs.umass.edu (vis-www.cs.umass.edu)... failed: Name or service not known.
# wget: unable to resolve host address ‘vis-www.cs.umass.edu’
# --2026-04-06 23:17:05--  http://vis-www.cs.umass.edu/fddb/FDDB-folds.tgz
# Resolving vis-www.cs.umass.edu (vis-www.cs.umass.edu)... failed: Name or service not known.
# wget: unable to resolve host address ‘vis-www.cs.umass.edu’
# tar: originalPics.tar.gz: Cannot open: No such file or directory
# tar: Error is not recoverable: exiting now
# tar: FDDB-folds.tgz: Cannot open: No such file or directory
# tar: Error is not recoverable: exiting now

# %%
detector = MTCNN()

# %%
from google.colab import files
uploaded = files.upload()

image_path = list(uploaded.keys())[0]
print(f"\nProcessing: {image_path}")

faces = detect_faces(image_path, show=True)
print("Faces detected:", faces)
# Out:
#      <input type="file" id="files-4a198635-4f89-4935-9bb1-93a7633c335e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4a198635-4f89-4935-9bb1-93a7633c335e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
